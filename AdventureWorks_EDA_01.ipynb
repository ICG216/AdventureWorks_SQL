# %% [markdown]
# # <center> **Adventure Works Project** </center>

# %% [markdown]
# This project involves exploratory data analysis (EDA) on an Azure-based SQL database for a fictional business, utilizing SQL queries within a Jupyter Notebook environment. The goal is to uncover key business insights, including customer purchasing patterns, product category performance, revenue generation, and order quantity distribution. By leveraging joins, aggregations, and groupings, the analysis helps identify top products, most valuable customers, and overall business trends, supporting strategic decision-making. The project combines SQL queries and Python for interactive analysis and data-driven insights.

# %%
# %load_ext sql

# %% [markdown]
# **Update the connection string in the notebook (replace with your Azure SQL database credentials):**
#    ```bash
# connection_string = "mssql+pyodbc://<username>:<password>@<server>/<database>?driver=ODBC+Driver+17+for+SQL+Server"
#  ```

# %%
# %%sql
# SELECT TABLE_NAME
# FROM INFORMATION_SCHEMA.TABLES;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [('database_firewall_rules',),
#  ('Customer',),
#  ('ProductModel',),
#  ('vProductModelCatalogDescription',),
#  ('ProductDescription',),
#  ('Product',),
#  ('ProductModelProductDescription',),
#  ('vProductAndDescription',),
#  ('ProductCategory',),
#  ('vGetAllCategories',),
#  ('BuildVersion',),
#  ('ErrorLog',),
#  ('Address',),
#  ('CustomerAddress',),
#  ('SalesOrderDetail',),
#  ('SalesOrderHeader',)]

# %% [markdown]
# ## Exploratory Data Analytics (EDA):

# %% [markdown]
# **1. What are the top 10 best-selling products by total revenue?**

# %%
# %%sql
# SELECT TOP 10
#     p.ProductID,
#     p.Name AS ProductName,
#     SUM(od.UnitPrice * od.OrderQty) AS TotalRevenue
# FROM
#     SalesLT.SalesOrderDetail od
# JOIN
#     SalesLT.Product p ON od.ProductID = p.ProductID
# GROUP BY
#     p.ProductID, p.Name
# ORDER BY
#     TotalRevenue DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [(976, 'Road-350-W Yellow, 48', Decimal('38612.4730')),
#  (969, 'Touring-1000 Blue, 60', Decimal('37191.4920')),
#  (783, 'Mountain-200 Black, 42', Decimal('37178.8380')),
#  (782, 'Mountain-200 Black, 38', Decimal('35801.8440')),
#  (957, 'Touring-1000 Yellow, 60', Decimal('23745.3372')),
#  (967, 'Touring-1000 Blue, 50', Decimal('22887.0720')),
#  (780, 'Mountain-200 Silver, 42', Decimal('20879.9100')),
#  (973, 'Road-350-W Yellow, 40', Decimal('20411.8800')),
#  (784, 'Mountain-200 Black, 46', Decimal('19277.9160')),
#  (974, 'Road-350-W Yellow, 42', Decimal('18949.0286'))]

# %% [markdown]
# **2. Which products do customers buy most frequently?**

# %%
# %%sql
# SELECT TOP 10
#     p.ProductID,
#     p.Name AS ProductName,
#     COUNT(od.SalesOrderDetailID) AS PurchaseCount
# FROM
#     SalesLT.SalesOrderDetail od
# JOIN
#     SalesLT.Product p ON od.ProductID = p.ProductID
# GROUP BY
#     p.ProductID, p.Name
# ORDER BY
#     PurchaseCount DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [(864, 'Classic Vest, S', 10),
#  (715, 'Long-Sleeve Logo Jersey, L', 10),
#  (712, 'AWC Logo Cap', 9),
#  (884, 'Short-Sleeve Classic Jersey, XL', 9),
#  (876, 'Hitch Rack - 4-Bike', 8),
#  (883, 'Short-Sleeve Classic Jersey, L', 8),
#  (877, 'Bike Wash - Dissolver', 7),
#  (948, 'Front Brakes', 7),
#  (880, 'Hydration Pack - 70 oz.', 7),
#  (938, 'LL Road Pedal', 7)]

# %% [markdown]
# **3. What is the average order value (AOV) across all customers?**

# %%
# %%sql
# SELECT
#     AVG(od.UnitPrice * od.OrderQty) AS AverageOrderValue
# FROM
#     SalesLT.SalesOrderDetail od;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [(Decimal('1317.3485'),)]

# %% [markdown]
# **4. Which products have the highest profit margins?**

# %%
# %%sql
# SELECT TOP 10
#     p.ProductID,
#     p.Name AS ProductName,
#     (p.ListPrice - p.StandardCost) AS ProfitMargin
# FROM
#     SalesLT.Product p
# ORDER BY
#     ProfitMargin DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [(771, 'Mountain-100 Silver, 38', Decimal('1487.8356')),
#  (772, 'Mountain-100 Silver, 42', Decimal('1487.8356')),
#  (773, 'Mountain-100 Silver, 44', Decimal('1487.8356')),
#  (774, 'Mountain-100 Silver, 48', Decimal('1487.8356')),
#  (775, 'Mountain-100 Black, 38', Decimal('1476.8956')),
#  (776, 'Mountain-100 Black, 42', Decimal('1476.8956')),
#  (777, 'Mountain-100 Black, 44', Decimal('1476.8956')),
#  (778, 'Mountain-100 Black, 48', Decimal('1476.8956')),
#  (749, 'Road-150 Red, 62', Decimal('1406.9758')),
#  (750, 'Road-150 Red, 44', Decimal('1406.9758'))]

# %% [markdown]
# **5. Which geographic regions have the highest sales?**

# %%
# %%sql
# SELECT
#     a.City,
#     SUM(od.UnitPrice * od.OrderQty) AS TotalSales
# FROM
#     SalesLT.SalesOrderHeader o
# JOIN
#     SalesLT.SalesOrderDetail od ON o.SalesOrderID = od.SalesOrderID
# JOIN
#     SalesLT.Address a ON o.ShipToAddressID = a.AddressID
# GROUP BY
#     a.City
# ORDER BY
#     TotalSales DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [('London', Decimal('154303.6008')),
#  ('Woolston', Decimal('90341.5338')),
#  ('Union City', Decimal('68142.6132')),
#  ('Liverpool', Decimal('65218.8776')),
#  ('Fullerton', Decimal('60526.9980')),
#  ('Gloucestershire', Decimal('53248.6920')),
#  ('Sherman Oaks', Decimal('47848.0260')),
#  ('Cerritos', Decimal('34208.9340')),
#  ('Van Nuys', Decimal('33319.9860')),
#  ('Milton Keynes', Decimal('30900.1746')),
#  ('West Sussex', Decimal('30600.9960')),
#  ('Santa Fe', Decimal('11528.8440')),
#  ('Englewood', Decimal('10585.0500')),
#  ('Las Vegas', Decimal('5535.2246')),
#  ('Oxnard', Decimal('3774.3240')),
#  ('Santa Ana', Decimal('2778.2902')),
#  ('Daly City', Decimal('2527.1280')),
#  ('Cambridge', Decimal('1929.5940')),
#  ('El Segundo', Decimal('1901.4060')),
#  ('Camarillo', Decimal('1732.8900')),
#  ('Oxon', Decimal('858.9000')),
#  ('Auburn', Decimal('713.7960')),
#  ('High Wycombe', Decimal('524.6640')),
#  ('Sandy', Decimal('500.3040')),
#  ('Culver City', Decimal('221.2560')),
#  ('Alhambra', Decimal('97.5688')),
#  ('Wokingham', Decimal('63.9000')),
#  ('Abingdon', Decimal('37.7580')),
#  ('Maidenhead', Decimal('31.5840'))]

# %% [markdown]
# **6. What is the distribution of order quantities across different product categories and what is the total revenue for each category?**

# %%
# %%sql
# SELECT
#     pc.Name AS CategoryName,
#     SUM(od.OrderQty) AS TotalQuantity,
#     SUM(od.UnitPrice * od.OrderQty) AS TotalRevenue
# FROM
#     SalesLT.SalesOrderDetail od
# JOIN
#     SalesLT.Product p ON od.ProductID = p.ProductID
# JOIN
#     SalesLT.ProductCategory pc ON p.ProductCategoryID = pc.ProductCategoryID
# GROUP BY
#     pc.Name
# ORDER BY
#     TotalRevenue DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [('Touring Bikes', 252, Decimal('221081.9622')),
#  ('Road Bikes', 222, Decimal('185513.0436')),
#  ('Mountain Bikes', 209, Decimal('173085.8460')),
#  ('Mountain Frames', 128, Decimal('54949.6020')),
#  ('Road Frames', 60, Decimal('24346.5840')),
#  ('Touring Frames', 39, Decimal('19066.2600')),
#  ('Jerseys', 230, Decimal('7094.1662')),
#  ('Vests', 121, Decimal('4416.4250')),
#  ('Cranksets', 22, Decimal('3968.8680')),
#  ('Shorts', 80, Decimal('3321.7254')),
#  ('Pedals', 84, Decimal('2996.4960')),
#  ('Helmets', 124, Decimal('2552.5205')),
#  ('Bike Racks', 32, Decimal('2304.0000')),
#  ('Hydration Packs', 50, Decimal('1649.7000')),
#  ('Bottom Brackets', 22, Decimal('1320.1680')),
#  ('Derailleurs', 21, Decimal('1296.6300')),
#  ('Handlebars', 27, Decimal('1192.9680')),
#  ('Saddles', 39, Decimal('1010.3040')),
#  ('Gloves', 57, Decimal('837.5580')),
#  ('Brakes', 13, Decimal('830.7000')),
#  ('Socks', 66, Decimal('349.1716')),
#  ('Caps', 52, Decimal('278.5102')),
#  ('Cleaners', 55, Decimal('255.5925')),
#  ('Bottles and Cages', 54, Decimal('159.4804')),
#  ('Chains', 8, Decimal('97.1520')),
#  ('Tires and Tubes', 20, Decimal('27.4800'))]

# %% [markdown]
# **7. What are the top 5 most frequent order days of the week?**

# %%
# %%sql
# SELECT
#     DATENAME(WEEKDAY, o.OrderDate) AS OrderDay,
#     COUNT(o.SalesOrderID) AS OrderCount
# FROM
#     SalesLT.SalesOrderHeader o
# GROUP BY
#     DATENAME(WEEKDAY, o.OrderDate)
# ORDER BY
#     OrderCount DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [('Sunday', 32)]

# %% [markdown]
# **8. Which customers have the highest average order value (AOV)?**

# %%
# %%sql
# SELECT
#     c.CustomerID,
#     c.FirstName,
#     c.LastName,
#     AVG(od.UnitPrice * od.OrderQty) AS AverageOrderValue
# FROM
#     SalesLT.Customer c
# JOIN
#     SalesLT.SalesOrderHeader o ON c.CustomerID = o.CustomerID
# JOIN
#     SalesLT.SalesOrderDetail od ON o.SalesOrderID = od.SalesOrderID
# GROUP BY
#     c.CustomerID, c.FirstName, c.LastName
# ORDER BY
#     AverageOrderValue DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [(29660, 'Anthony', 'Chor', Decimal('2392.4013')),
#  (29736, 'Terry', 'Eminhizer', Decimal('2100.9659')),
#  (29932, 'Rebecca', 'Laszlo', Decimal('1901.7390')),
#  (29546, 'Christopher', 'Beck', Decimal('1765.7197')),
#  (30050, 'Krishna', 'Sunkammurali', Decimal('1742.2472')),
#  (29957, 'Kevin', 'Liu', Decimal('1584.7119')),
#  (29796, 'Jon', 'Grande', Decimal('1417.8016')),
#  (29877, 'Joyce', 'Jarvis', Decimal('1323.1312')),
#  (29929, 'Jeffrey', 'Kurtz', Decimal('1210.5399')),
#  (29938, 'Frank', 'Campbell', Decimal('1103.5140')),
#  (30113, 'Raja', 'Venugopal', Decimal('1055.2067')),
#  (29922, 'Pamala', 'Kotc', Decimal('972.9076')),
#  (29531, 'Cory', 'Booth', Decimal('922.5374')),
#  (29644, 'Brigid', 'Cavendish', Decimal('858.9000')),
#  (29485, 'Catherine', 'Abel', Decimal('774.8833')),
#  (29653, 'Pei', 'Chow', Decimal('678.1672')),
#  (30019, 'Matthew', 'Miller', Decimal('570.9820')),
#  (30102, 'Roger', 'Van Houten', Decimal('482.3985')),
#  (29982, 'Melissa', 'Marple', Decimal('421.1880')),
#  (30027, 'Joseph', 'Mitzner', Decimal('406.7725')),
#  (29975, 'Walter', 'Mays', Decimal('396.8986')),
#  (29847, 'David', 'Hodgson', Decimal('356.8980')),
#  (29638, 'Rosmarie', 'Carroll', Decimal('346.5780')),
#  (30089, 'Michael John', 'Troyer', Decimal('308.9720')),
#  (30033, 'Vassar', 'Stern', Decimal('250.1520')),
#  (29568, 'Donald', 'Blanton', Decimal('237.6757')),
#  (29612, 'Richard', 'Byham', Decimal('174.8880')),
#  (29584, 'Walter', 'Brian', Decimal('73.7520')),
#  (30072, 'Andrea', 'Thomsen', Decimal('63.9000')),
#  (30025, 'Linda', 'Mitchell', Decimal('37.7580')),
#  (29781, 'Guy', 'Gilbert', Decimal('32.5229')),
#  (29741, 'Janeth', 'Esteves', Decimal('31.5840'))]

# %% [markdown]
# **10.What are the most common order quantities for products?**

# %%
# %%sql
# SELECT TOP 15
#     p.Name AS ProductName,
#     od.OrderQty,
#     COUNT(*) AS Frequency
# FROM
#     SalesLT.SalesOrderDetail od
# JOIN
#     SalesLT.Product p ON od.ProductID = p.ProductID
# GROUP BY
#     p.Name, od.OrderQty
# ORDER BY
#     Frequency DESC;
# Out:
#  * mssql+pyodbc://ICG216:***@upgradeservericg.database.windows.net/adventureworks_sql?driver=ODBC+Driver+17+for+SQL+Server
# Done.
# [('Long-Sleeve Logo Jersey, L', 2, 4),
#  ('LL Mountain Frame - Black, 48', 1, 4),
#  ('Front Brakes', 1, 4),
#  ('Mountain-400-W Silver, 40', 2, 4),
#  ('LL Mountain Handlebars', 1, 3),
#  ('HL Mountain Handlebars', 1, 3),
#  ('Classic Vest, S', 3, 3),
#  ('Hitch Rack - 4-Bike', 3, 3),
#  ('Hydration Pack - 70 oz.', 9, 3),
#  ('Short-Sleeve Classic Jersey, S', 6, 3),
#  ('HL Touring Frame - Blue, 60', 1, 3),
#  ('HL Touring Seat/Saddle', 1, 3),
#  ('HL Mountain Pedal', 1, 3),
#  ('LL Road Pedal', 3, 3),
#  ('LL Mountain Frame - Silver, 40', 2, 3)]
